# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.9/906.9 kB 15.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="o1G25tPEARyWaIKqeWcf")
project = rf.workspace("studytest-yqymk").project("zkzk-zkzk")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to zkzk-zkzk-4 in yolov8:: 100%|██████████| 9768/9768 [00:01<00:00, 7527.17it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect \
mode=train \
model=yolov8l.pt \
data=/kaggle/working/zkzk-zkzk-4/data.yaml \
epochs=50 \
imgsz=640
# Out:
# ...
# 100%|██████████████████████████████████████| 83.7M/83.7M [00:01<00:00, 81.7MB/s]
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model=/kaggle/working/runs/detect/train/weights/best.pt \
data=/kaggle/working/zkzk-zkzk-4/data.yaml
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
# ...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 4.12MB/s]
# val: Scanning /kaggle/working/zkzk-zkzk-4/valid/labels.cache... 395 images, 6 ba
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        395        491      0.869      0.889       0.91      0.798
#                     id         62         63      0.917      0.937      0.953      0.902
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/kaggle/working/runs/detect/train/weights/best.pt \
conf=0.50 \
source=/kaggle/working/zkzk-zkzk-4/test/images
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/268 /kaggle/working/zkzk-zkzk-4/test/images/1000_jpg.rf.831b90617b48e4107f89b60838be782c.jpg: 640x640 1 id_rotated, 62.6ms
# image 2/268 /kaggle/working/zkzk-zkzk-4/test/images/1001_1_jpg.rf.dd7a41ceff91b3a749aafd1004a5e142.jpg: 640x640 1 id_rotated_right, 45.1ms
# image 3/268 /kaggle/working/zkzk-zkzk-4/test/images/1003_1_jpg.rf.ba45346838235b6df30274ba1e9af31a.jpg: 640x640 1 id_rotated, 45.0ms
# image 4/268 /kaggle/working/zkzk-zkzk-4/test/images/1003_3_jpg.rf.e2a9466f91483d60eb98b1a92164d556.jpg: 640x640 1 id_rotated_down, 44.9ms
# image 5/268 /kaggle/working/zkzk-zkzk-4/test/images/1004_jpg.rf.49f9897e86023a90fd33d6f6b917b5d4.jpg: 640x640 1 id_rotated, 44.9ms
# image 6/268 /kaggle/working/zkzk-zkzk-4/test/images/1005_3_jpg.rf.86a957cc05e24f41b36261788d922509.jpg: 640x640 1 id_rotated, 38.6ms
# ...

# %%
# !yolo task=detect \
mode=train \
model=/kaggle/working/runs/detect/train/weights/best.pt \
data=/kaggle/working/zkzk-zkzk-4/data.yaml \
epochs=50 \
imgsz=640
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...
